# %% [markdown]
#  **In this project we will create a Convolutional Neural Network which will be able to predict whether a plant is suffering from a disease. We will use different layers and other hyperparameters for building, training and testing this classifictaion model.We will be using tensorflow and keras for this project.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from keras.preprocessing import image
from tensorflow.keras.utils import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Next we will import all the required libraries. As we are making a CNN model we will import all the required layers, activations, optimizers, etc.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/kaggle/input/corn-tomato-potato-disease/Data/Plant_images/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image

# %% [markdown]
# Now we will observe some of the iamges that are their in our dataset. We will plot 12 images here using the matplotlib library.

# %%
#Converting Images to array 
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))  
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# After visualizing the images let us move forward and create a function which will convert the images into a numpy array. It is required because we will normalize our dataset after this.

# %%
dir = "/kaggle/input/corn-tomato-potato-disease/Data/Plant_images"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# Now we will convert all the images into numpy array.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0    300
# 1    300
# 2    300
# dtype: int64

# %% [markdown]
# We will also observe the number of images under different classes to see if the dataset is balanced or not

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# Next we will observe the shape of the image.

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %% [markdown]
# Checking the total number of the images which is the length of the labels list.

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Next we will use sklearn train_test_split to split the dataset into testing and training data. Here I have taken test size as 0.2 so my data will be divided into 80% training and 20% testing data.

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %% [markdown]
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(64, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 85, 85, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 85, 85, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 42, 42, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 112896)            0
# _________________________________________________________________
# dense (Dense)                (None, 64)                7225408
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 7,244,995
# Trainable params: 7,244,995
# Non-trainable params: 0
# _________________________________________________________________
# 2023-01-14 16:06:03.988262: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Binary Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Next we will split the dataset into validation and training data.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (x_val, y_val))
# Out:
# 2023-01-14 16:06:05.726422: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 5/5 [==============================] - 12s 2s/step - loss: 0.8877 - accuracy: 0.5642 - val_loss: 0.5637 - val_accuracy: 0.6458
# Epoch 2/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.4588 - accuracy: 0.7726 - val_loss: 0.3191 - val_accuracy: 0.9653
# Epoch 3/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.2797 - accuracy: 0.9253 - val_loss: 0.2861 - val_accuracy: 0.8819
# Epoch 4/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.2101 - accuracy: 0.9410 - val_loss: 0.1826 - val_accuracy: 0.9444
# Epoch 5/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.1528 - accuracy: 0.9583 - val_loss: 0.1266 - val_accuracy: 0.9792
# Epoch 6/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.1149 - accuracy: 0.9601 - val_loss: 0.1386 - val_accuracy: 0.9653
# Epoch 7/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0892 - accuracy: 0.9861 - val_loss: 0.0917 - val_accuracy: 0.9861
# Epoch 8/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0633 - accuracy: 0.9878 - val_loss: 0.0889 - val_accuracy: 0.9653
# Epoch 9/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0575 - accuracy: 0.9878 - val_loss: 0.0598 - val_accuracy: 0.9931
# Epoch 10/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0414 - accuracy: 0.9948 - val_loss: 0.0550 - val_accuracy: 0.9861
# Epoch 11/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0352 - accuracy: 0.9948 - val_loss: 0.0472 - val_accuracy: 0.9931
# Epoch 12/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0289 - accuracy: 0.9948 - val_loss: 0.0418 - val_accuracy: 0.9861
# Epoch 13/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0253 - accuracy: 0.9965 - val_loss: 0.0393 - val_accuracy: 0.9861
# Epoch 14/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0352 - val_accuracy: 0.9861
# Epoch 15/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.0326 - val_accuracy: 0.9861
# Epoch 16/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9861
# Epoch 17/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0286 - val_accuracy: 0.9861
# Epoch 18/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 0.9861
# Epoch 19/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 0.9861
# Epoch 20/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0250 - val_accuracy: 0.9861
# Epoch 21/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9861
# Epoch 22/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9861
# Epoch 23/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9861
# Epoch 24/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9861
# Epoch 25/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9861
# Epoch 26/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9861
# Epoch 27/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0195 - val_accuracy: 0.9861
# Epoch 28/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 0.9931
# Epoch 29/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9931
# Epoch 30/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9861
# Epoch 31/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9931
# Epoch 32/50
# 5/5 [==============================] - 11s 2s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9861
# Epoch 33/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9931
# Epoch 34/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 0.9861
# Epoch 35/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 0.9931
# Epoch 36/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 0.9931
# Epoch 37/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 0.9931
# Epoch 38/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 0.9931
# Epoch 39/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 0.9931
# Epoch 40/50
# 5/5 [==============================] - 9s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 0.9931
# Epoch 41/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9931
# Epoch 42/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 0.9931
# Epoch 43/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 0.9931
# Epoch 44/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 0.9931
# Epoch 45/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9931
# Epoch 46/50
# 5/5 [==============================] - 10s 2s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9931
# Epoch 47/50
# 5/5 [==============================] - 10s 2s/step - loss: 9.8430e-04 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 0.9931
# Epoch 48/50
# 5/5 [==============================] - 10s 2s/step - loss: 9.2925e-04 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 0.9931
# Epoch 49/50
# 5/5 [==============================] - 10s 2s/step - loss: 8.6549e-04 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9931
# Epoch 50/50
# 5/5 [==============================] - 10s 2s/step - loss: 8.0221e-04 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9931

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 10 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already raeched a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
model.save("Data/plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('Data/plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('Data/plant_model_weights.h5')

# %% [markdown]
# Saving the model using different techniques.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the trainig history.

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 1s 108ms/step - loss: 0.0479 - accuracy: 0.9889
# Test Accuracy: 98.88888597488403

# %% [markdown]
# Evaluating the model to know the accuracy of the model.

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# Next we will use our model to predict predicting the testing dataset label.

# %%
# Plotting image to compare
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[10])])
print("Predicted : ",all_labels[np.argmax(y_pred[10])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight

# %% [markdown]
# Printing out the original and the predicted label.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We started with loading the dataset and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the plant diseases using the image supplied to model.
# This model is highly beneficial as it can be used by different agricultural firms and farmers to increase their yield and stop wastage of crops due to disease.
